# %%
import pandas as pd

# %%
df = pd.read_csv('incidents.csv')
wa=df[df['state'] == 'Washington']
wa
# Out:
#         incident_id        date       state            city_or_county  \
# 45           483817  2013-03-31  Washington                    Auburn
# 54           484333  2013-04-21  Washington               Federal Way
# 153          491281  2013-07-29  Washington                   Granger
# 193          480071  2013-09-15  Washington                    Yakima
# 323           92345  2014-01-01  Washington                Georgetown
# ...             ...         ...         ...                       ...
# 239176      1079791  2018-03-28  Washington                   Seattle
# 239399      1080903  2018-03-29  Washington                     Pasco
# 239401      1081610  2018-03-29  Washington               Walla Walla
# 239402      1081612  2018-03-29  Washington                    Yakima
# 239671      1082061  2018-03-31  Washington  Spokane (Spokane Valley)
#
#         n_killed  n_injured  latitude  longitude
# 45             3          2   47.3149   -122.224
# 54             5          0   47.3030   -122.310
# 153            0          4   46.3421   -120.187
# 193            0          6   46.5854   -120.538
# 323            0          1   47.5498   -122.318
# ...          ...        ...       ...        ...
# 239176         0          0   47.6138   -122.332
# 239399         0          1       NaN        NaN
# 239401         0          0   46.0737   -118.312
# 239402         0          1   46.6173   -120.512
# 239671         0          0   47.6638   -117.235
#
# [3434 rows x 8 columns]

# %%
import pandas as pd
import datetime
from pandarallel import pandarallel
from nltk.sentiment.vader import SentimentIntensityAnalyzer
pandarallel.initialize(nb_workers=32)
import twint
import time
import random
import nltk
import nest_asyncio
nest_asyncio.apply()
__import__('IPython').embed()

nltk.download('vader_lexicon')
# Out:
# INFO: Pandarallel will run on 32 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/yeraf/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
radius = 2
over = 14
def get_tweet_loc(params):
    for _ in range(10):
        try:
            c = twint.Config()
            c.Search = params['keyword']
            c.Limit = 100
            c.Geo = f"{str(params['lat'])},{str(params['lng'])},{str(params['distance'])}{params['unit']}"
            c.Pandas = True
            c.Since = params['since']
            c.Until = params['until']
            twint.run.Search(c)
            sid = SentimentIntensityAnalyzer()
            stat = {"pos": 0, "neg": 0, "neu": 0, "comp": 0, "scrape": True}
            print(twint.storage.panda.Tweets_df.shape)
            if twint.storage.panda.Tweets_df.shape[0] > 0:
                tweets = twint.storage.panda.Tweets_df['tweet']
                for tweet in tweets:
                    senvalue = sid.polarity_scores(tweet)
                    stat['pos'] += senvalue["pos"]
                    stat['neg'] += senvalue["neg"]
                    stat['neu'] += senvalue["neu"]
                    stat['comp'] += senvalue["compound"]
                stat['neg'] /= tweets.shape[0]
                stat['pos'] /= tweets.shape[0]
                stat['neu'] /= tweets.shape[0]
                stat['comp'] /= tweets.shape[0] 
            return stat
        except Exception as e:
            time.sleep(random.random() * 300)
            print('error: ', e)
            continue
    return {"pos": 0, "neg": 0, "neu": 0, "comp": 0, "scrape": True}

def get_loca_polar(r):
    response = get_tweet_loc({
            "keyword": "gun",
            "lat": r['latitude'],
            "lng": r['longitude'],
            "distance": radius,
            "unit": "km",
            "since": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') - datetime.timedelta(days=over)).strftime('%Y-%m-%d'),
            "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
        })
    print(response)
    if response:
        r['pos'] = response['pos']
        r['neg'] = response['neg']
        r['neu'] = response['neu']
        r['comp'] = response['comp']
        r['scrape'] = response['scrape']
    else:
        r['pos'] = 0
        r['neg'] = 0
        r['neu'] = 0
        r['comp'] = 0
        return r

wa_polar = wa.parallel_apply(get_loca_polar, axis=1)
wa_polar.to_csv('wa_polar_1_14d.csv')
# Out:
# error:  This event loop is already running
# error:  This event loop is already running
# error:  This event loop is already running
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-27:
# Traceback (most recent call last):
# Process ForkPoolWorker-29:
# Traceback (most recent call last):
# Process ForkPoolWorker-31:
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-26:
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# RuntimeError: This event loop is already running
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#
# During handling of the above exception, another exception occurred:
#
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# Process ForkPoolWorker-25:
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-11:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# RuntimeError: This event loop is already running
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-15:
# RuntimeError: This event loop is already running
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# Process ForkPoolWorker-21:
# Traceback (most recent call last):
# Process ForkPoolWorker-22:
# Traceback (most recent call last):
# Process ForkPoolWorker-18:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# Process ForkPoolWorker-6:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# RuntimeError: This event loop is already running
# Process ForkPoolWorker-2:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-10:
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#
# During handling of the above exception, another exception occurred:
#
# Process ForkPoolWorker-14:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# Process ForkPoolWorker-13:
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# Process ForkPoolWorker-9:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-19:
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# Process ForkPoolWorker-3:
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# RuntimeError: This event loop is already running
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# RuntimeError: This event loop is already running
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# Process ForkPoolWorker-8:
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# Traceback (most recent call last):
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-17:
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# Process ForkPoolWorker-4:
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# RuntimeError: This event loop is already running
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# RuntimeError: This event loop is already running
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#
# During handling of the above exception, another exception occurred:
#
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "<ipython-input-4-81c4591b7121>", line 13, in get_tweet_loc
#     twint.run.Search(c)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 410, in Search
#     run(config, callback)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
# RuntimeError: This event loop is already running
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
# RuntimeError: This event loop is already running
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/twint/run.py", line 329, in run
#     get_event_loop().run_until_complete(Twint(config).main(callback))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#
# During handling of the above exception, another exception occurred:
#
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError: This event loop is already running
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
# RuntimeError: This event loop is already running
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 475, in run_until_complete
#     self.run_forever()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/asyncio/base_events.py", line 429, in run_forever
#     raise RuntimeError('This event loop is already running')
# Traceback (most recent call last):
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Traceback (most recent call last):
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# ...
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
# KeyboardInterrupt
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/data_types/dataframe.py", line 31, in worker
#     return df.apply(func, *args, **kwargs)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 64, in global_worker
#     return _func(x)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/frame.py", line 7552, in apply
#     return op.get_result()
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandarallel/pandarallel.py", line 116, in wrapper
#     **kwargs
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 185, in get_result
#     return self.apply_standard()
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
# KeyboardInterrupt
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
# KeyboardInterrupt
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 276, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "<ipython-input-4-81c4591b7121>", line 33, in get_tweet_loc
#     time.sleep(random.random() * 300)
#   File "/home/yeraf/.pyenv/versions/3.6.10/envs/us-gun/lib/python3.6/site-packages/pandas/core/apply.py", line 305, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-4-81c4591b7121>", line 46, in get_loca_polar
#     "until": (datetime.datetime.strptime(r['date'], '%Y-%m-%d') + datetime.timedelta(days=over)).strftime('%Y-%m-%d')
